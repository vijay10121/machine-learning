# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/student performance/Student_performance.csv")

# %%
df = df.sample(100000)
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 645279      645280                     14.4                   84.9
# 983179      983180                     11.0                   67.5
# 368413      368414                     11.6                   67.6
# 219398      219399                     16.3                   87.9
# 683043      683044                      9.4                   71.8
# ...            ...                      ...                    ...
# 850485      850486                      8.7                   87.9
# 238752      238753                      4.2                   71.9
# 642418      642419                     24.2                   87.0
# 448503      448504                     24.0                   99.9
# 626482      626483                     15.8                   79.6
#
#         class_participation  total_score grade
# 645279                  6.3         72.6     B
# 983179                  3.1         74.2     B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 645279 to 626482
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   student_id               100000 non-null  int64
#  1   weekly_self_study_hours  100000 non-null  float64
#  2   attendance_percentage    100000 non-null  float64
#  3   class_participation      100000 non-null  float64
#  4   total_score              100000 non-null  float64
#  5   grade                    100000 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#           student_id  weekly_self_study_hours  attendance_percentage  \
# count  100000.000000            100000.000000          100000.000000
# mean   499527.893210                15.004212              84.668053
# std    288080.504154                 6.892939               9.438651
# min        17.000000                 0.000000              50.000000
# 25%    250789.000000                10.200000              78.200000
# 50%    498825.500000                15.000000              85.000000
# 75%    748670.500000                19.700000              91.700000
# max    999994.000000                40.000000             100.000000
#
#        class_participation    total_score
# count        100000.000000  100000.000000
# mean              5.989835      84.250691
# std               1.953027      15.426007
# min               0.000000      14.400000
# 25%               4.700000      73.800000
# 50%               6.000000      87.400000
# 75%               7.400000     100.000000
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.displot(df["weekly_self_study_hours"])

# %%
sns.displot(df["attendance_percentage"])

# %%
df = df.iloc[:,:-1]

# %%
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 645279      645280                     14.4                   84.9
# 983179      983180                     11.0                   67.5
# 368413      368414                     11.6                   67.6
# 219398      219399                     16.3                   87.9
# 683043      683044                      9.4                   71.8
# ...            ...                      ...                    ...
# 850485      850486                      8.7                   87.9
# 238752      238753                      4.2                   71.9
# 642418      642419                     24.2                   87.0
# 448503      448504                     24.0                   99.9
# 626482      626483                     15.8                   79.6
#
#         class_participation  total_score
# 645279                  6.3         72.6
# 983179                  3.1         74.2
# ...

# %%
nf = np.power(df["attendance_percentage"],3)

# %%
nf
# Out:
# 645279    611960.049
# 983179    307546.875
# 368413    308915.776
# 219398    679151.439
# 683043    370146.232
#              ...
# 850485    679151.439
# 238752    371694.959
# 642418    658503.000
# 448503    997002.999
# 626482    504358.336
# Name: attendance_percentage, Length: 100000, dtype: float64

# %%
sns.displot(nf)

# %%
df["attendance_percentage"] = nf

# %%
sns.displot(df["class_participation"])

# %%
df.skew()
# Out:
# student_id                 0.005221
# weekly_self_study_hours    0.085915
# attendance_percentage      0.179676
# class_participation       -0.114084
# total_score               -0.814669
# dtype: float64

# %%
sns.displot(df["attendance_percentage"])

# %%
sns.boxplot(x=df["class_participation"])
# Out:
# <Axes: xlabel='class_participation'>

# %%
sns.boxplot(x=df["attendance_percentage"])
# Out:
# <Axes: xlabel='attendance_percentage'>

# %%
sns.boxplot(x=df["weekly_self_study_hours"])
# Out:
# <Axes: xlabel='weekly_self_study_hours'>

# %%
X = df.iloc[:,1:-1]

# %%
X
# Out:
#         weekly_self_study_hours  attendance_percentage  class_participation
# 645279                     14.4             611960.049                  6.3
# 983179                     11.0             307546.875                  3.1
# 368413                     11.6             308915.776                  8.2
# 219398                     16.3             679151.439                  3.8
# 683043                      9.4             370146.232                  8.4
# ...                         ...                    ...                  ...
# 850485                      8.7             679151.439                  8.4
# 238752                      4.2             371694.959                  5.1
# 642418                     24.2             658503.000                  2.8
# 448503                     24.0             997002.999                  4.6
# 626482                     15.8             504358.336                  7.4
#
# [100000 rows x 3 columns]

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 645279     72.6
# 983179     74.2
# 368413     84.4
# 219398     86.7
# 683043     70.6
#           ...
# 850485     60.2
# 238752     54.5
# 642418    100.0
# 448503    100.0
# 626482     88.0
# Name: total_score, Length: 100000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33, random_state=42)

# %%
num_columns=["weekly_self_study_hours","attendance_percentage","class_participation"]

# %%
z = np.abs((X_train - X_train.mean()) / X_train.std())

mask = (z < 3).all(axis=1)

X_train = X_train[mask]
y_train = y_train[mask]

# %%
X_train
# Out:
#         weekly_self_study_hours  attendance_percentage  class_participation
# 863693                      5.6             748613.312                  3.9
# 377113                     16.4             721734.273                  8.6
# 463937                     10.6            1000000.000                  9.3
# 349597                     18.7             553387.661                  4.0
# 706595                      0.0             425259.008                  6.5
# ...                         ...                    ...                  ...
# 944714                     17.0             851971.392                  6.1
# 207423                     19.8             413493.625                  0.7
# 377650                     19.8             751089.429                  2.6
# 127452                      6.8             557441.767                  7.5
# 724426                     26.1             487443.403                  5.8
#
# [67000 rows x 3 columns]

# %%
y_train
# Out:
# 863693     60.4
# 377113     70.9
# 463937     75.4
# 349597     96.3
# 706595     44.9
#           ...
# 944714     88.9
# 207423     88.9
# 377650    100.0
# 127452     77.7
# 724426     98.2
# Name: total_score, Length: 67000, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
    ]
)

# %%
from sklearn.linear_model import LinearRegression

pipeline = Pipeline(steps=[
    #("preprocessing", preprocessor),
    ("model", LinearRegression())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('model', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6597222861051169

# %%
#without outlier removal but with scaling
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6599861307408464

# %%
#without any preprocessing 
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6599861307408463
